# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

# %%
print(myvar)
print(type(a))
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# <class 'list'>

# %%
myvar = pd.Series(a,index=["x","y","z"])
myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
employee = { "Name":["Ash","Happy","Sam","Ram"],"Percentage":[97,99,90,87]}
empData = pd.DataFrame(employee)
print(empData)
# Out:
#     Name  Percentage
# 0    Ash          97
# 1  Happy          99
# 2    Sam          90
# 3    Ram          87

# %%
employee.update({"Class":[12,12,10,11]})
empData = pd.DataFrame(employee)

# %%
print(empData)
# Out:
#     Name  Percentage  Class
# 0    Ash          97     12
# 1  Happy          99     12
# 2    Sam          90     10
# 3    Ram          87     11

# %%
print(empData.loc[:])
# Out:
#     Name  Percentage  Class
# 0    Ash          97     12
# 1  Happy          99     12
# 2    Sam          90     10
# 3    Ram          87     11

# %%
print(empData.loc[0:2])
# Out:
#     Name  Percentage  Class
# 0    Ash          97     12
# 1  Happy          99     12
# 2    Sam          90     10

# %%
newData = pd.read_csv("data.csv")
newData
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(newData.to_string()) # to Print entire data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
pd.options.display.max_rows =9999

newData = pd.read_csv("data.csv")
print(newData)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(newData.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(newData.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
print(newData.tail(10))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(newData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %% [markdown]
# ***Cleaning Data***

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.isna().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
print(df["Calories"].to_string())
# Out:
# 0       409.1
# 1       479.0
# 2       340.0
# 3       282.4
# 4       406.0
# 5       300.0
# 6       374.0
# 7       253.3
# 8       195.1
# 9       269.0
# 10      329.3
# 11      250.7
# 12      345.3
# 13      379.3
# 14      275.0
# 15      215.2
# 16      300.0
# 17        NaN
# 18      323.0
# 19      243.0
# 20      364.2
# 21      282.0
# 22      300.0
# 23      246.0
# 24      334.5
# 25      250.0
# 26      241.0
# 27        NaN
# 28      280.0
# 29      380.3
# 30      243.0
# 31      180.1
# 32      299.0
# 33      223.0
# 34      361.0
# 35      415.0
# 36      300.0
# 37      300.0
# 38      300.0
# 39      266.0
# 40      180.1
# 41      286.0
# 42      329.4
# 43      400.0
# 44      397.0
# 45      273.0
# 46      387.6
# 47      300.0
# 48      298.0
# 49      397.6
# 50      380.2
# 51      643.1
# 52      263.0
# 53      486.0
# 54      238.0
# 55      450.7
# 56      413.0
# 57      305.0
# 58      226.4
# 59      321.0
# 60     1376.0
# 61     1034.4
# ...

# %%
new_df = df.dropna()
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
mean_calories = df["Calories"].mean()
print(mean_calories)
# Out:
# 375.79024390243916

# %%
df["Calories"].fillna(mean_calories,inplace=True)
print(df["Calories"].to_string())
# Out:
# 0       409.100000
# 1       479.000000
# 2       340.000000
# 3       282.400000
# 4       406.000000
# 5       300.000000
# 6       374.000000
# 7       253.300000
# 8       195.100000
# 9       269.000000
# 10      329.300000
# 11      250.700000
# 12      345.300000
# 13      379.300000
# 14      275.000000
# 15      215.200000
# 16      300.000000
# 17      375.790244
# 18      323.000000
# 19      243.000000
# 20      364.200000
# 21      282.000000
# 22      300.000000
# 23      246.000000
# 24      334.500000
# 25      250.000000
# 26      241.000000
# 27      375.790244
# 28      280.000000
# 29      380.300000
# 30      243.000000
# 31      180.100000
# 32      299.000000
# 33      223.000000
# 34      361.000000
# 35      415.000000
# 36      300.000000
# 37      300.000000
# 38      300.000000
# 39      266.000000
# 40      180.100000
# 41      286.000000
# 42      329.400000
# 43      400.000000
# 44      397.000000
# 45      273.000000
# 46      387.600000
# ...

# %%
df.isna().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
median_calories = df["Calories"].median()
print(median_calories)
# Out:
# 321.0

# %%
df["Calories"].fillna(median_calories,inplace=True)
print(df["Calories"].to_string())
# Out:
# 0       409.100000
# 1       479.000000
# 2       340.000000
# 3       282.400000
# 4       406.000000
# 5       300.000000
# 6       374.000000
# 7       253.300000
# 8       195.100000
# 9       269.000000
# 10      329.300000
# 11      250.700000
# 12      345.300000
# 13      379.300000
# 14      275.000000
# 15      215.200000
# 16      300.000000
# 17      375.790244
# 18      323.000000
# 19      243.000000
# 20      364.200000
# 21      282.000000
# 22      300.000000
# 23      246.000000
# 24      334.500000
# 25      250.000000
# 26      241.000000
# 27      375.790244
# 28      280.000000
# 29      380.300000
# 30      243.000000
# 31      180.100000
# 32      299.000000
# 33      223.000000
# 34      361.000000
# 35      415.000000
# 36      300.000000
# 37      300.000000
# 38      300.000000
# 39      266.000000
# 40      180.100000
# 41      286.000000
# 42      329.400000
# 43      400.000000
# 44      397.000000
# 45      273.000000
# 46      387.600000
# ...

# %%
df["Calories"].fillna(0,inplace=True)
print(df["Calories"].to_string())
# Out:
# 0       409.100000
# 1       479.000000
# 2       340.000000
# 3       282.400000
# 4       406.000000
# 5       300.000000
# 6       374.000000
# 7       253.300000
# 8       195.100000
# 9       269.000000
# 10      329.300000
# 11      250.700000
# 12      345.300000
# 13      379.300000
# 14      275.000000
# 15      215.200000
# 16      300.000000
# 17      375.790244
# 18      323.000000
# 19      243.000000
# 20      364.200000
# 21      282.000000
# 22      300.000000
# 23      246.000000
# 24      334.500000
# 25      250.000000
# 26      241.000000
# 27      375.790244
# 28      280.000000
# 29      380.300000
# 30      243.000000
# 31      180.100000
# 32      299.000000
# 33      223.000000
# 34      361.000000
# 35      415.000000
# 36      300.000000
# 37      300.000000
# 38      300.000000
# 39      266.000000
# 40      180.100000
# 41      286.000000
# 42      329.400000
# 43      400.000000
# 44      397.000000
# 45      273.000000
# 46      387.600000
# ...

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse     Calories
# 0          60    110       130   409.100000
# 1          60    117       145   479.000000
# 2          60    103       135   340.000000
# 3          45    109       175   282.400000
# 4          45    117       148   406.000000
# 5          60    102       127   300.000000
# 6          60    110       136   374.000000
# 7          45    104       134   253.300000
# 8          30    109       133   195.100000
# 9          60     98       124   269.000000
# 10         60    103       147   329.300000
# 11         60    100       120   250.700000
# 12         60    106       128   345.300000
# 13         60    104       132   379.300000
# 14         60     98       123   275.000000
# 15         60     98       120   215.200000
# 16         60    100       120   300.000000
# 17         45     90       112   375.790244
# 18         60    103       123   323.000000
# 19         45     97       125   243.000000
# ...

# %%
df.loc[60,'Duration'] = 55

# %%
print(df['Duration'].loc[60])
# Out:
# 55

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data.csv')

# %%
df.plot(kind ='scatter',x='Calories',y='Pulse')
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='Pulse'>
